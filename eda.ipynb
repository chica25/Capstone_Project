# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://builtin.com/jobs"

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Search the best Tech Jobs &amp; Startup Jobs from top companies &amp; startups. New jobs added daily." name="description"/>
# <meta content="INDEX,FOLLOW" name="robots"/>
# <title>Best Tech Jobs &amp; Startup Jobs 2024 | Built In</title>
# <link href="https://static.builtin.com/dist/images/favicon.png" rel="icon" type="image/x-icon"/>
# <link href="https://builtin.com/jobs" rel="canonical">
# <link href="https://www.googletagmanager.com/" rel="dns-prefetch"/>
# <link as="font" crossorigin="" href="https://static.builtin.com/dist/fonts/barlow-condensed-v12-latin-regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://static.builtin.com/dist/fonts/montserrat-v25-latin-regular.woff2" rel="preload" type="font/woff2"/>
# <link href="/jobs/css/main.bundle.95367963a0a6af0cfaf1.css" rel="stylesheet"/>
# <link href="https://static.builtin.com/dist/blaze/blaze.css" media="print" onload="this.media='all'" rel="stylesheet">
# <script>
#       (function(n,i,v,r,s,c,x,z){x=window.AwsRumClient={q:[],n:n,i:i,v:v,r:r,c:c};window[n]=function(c,p){x.q.push({c:c,p:p});};z=document.createElement('script');z.async=true;z.src=s;document.head.insertBefore(z,document.head.getElementsByTagName('script')[0]);})(
#         'cwr',
#         '940d51e6-7e6a-49a8-9f7b-e94f43abb061',
#         '1.0.0',
#         'us-west-2',
#         'https://client.rum.us-east-1.amazonaws.com/1.13.6/cwr.js',
#         {
#           sessionSampleRate: 0.1,
#           guestRoleArn: "arn:aws:iam::881910225067:role/cloudwatch-rum-default-role",
#           identityPoolId: "us-west-2:d73b976d-181c-499d-9df1-6c322fea90a9",
#           endpoint: "https://dataplane.rum.us-west-2.amazonaws.com",
#           telemetries: ["performance","errors","http"],
#           allowCookies: true,
#           enableXRay: true
#         }
#       );
#     </script>
# <script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-M7NGJ28');
#     </script>
# </link></link></head>
# <body>
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M7NGJ28" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <div data-auto_select="false" data-client_id="941473408521-r82mlse6rh2ar9loff8bgnbqtbp6inrs.apps.googleusercontent.com" data-existing_user_return_url="https://builtin.com/auth/externalauthenticate.html?redirectUrl=%2Fbilogin%3Fdestination%3D%252Fjobs" data-login_uri="https://accounts.builtin.com/External/OneTap" data-new_user_return_url="https://builtin.com/auth/externalauthenticate.html?redirectUrl=%2Fbilogin%3Fdestination%3D%252Fjobs" data-prompt_parent_id="g_id_onload" id="g_id_onload" style="position: absolute; top: 150px; right: 410px; width: 0; height: 0; z-index: 1001"><div><script async="" defer="" src="https://accounts.google.com/gsi/client"></script></div></div>
# <header class="header sticky-top">
# <div class="bg-app-primary text-white nav-height d-flex align-items-center"><div class="container h-100 d-flex justify-content-between"><a class="d-flex align-items-center" href="/"><img alt="Built In Logo" class="d-none d-lg-block" height="50" loading="lazy" src="https://static.builtin.com/dist/images/9.svg" width="110"/>
# <img alt="Built In Logo" class="d-lg-none" height="30" loading="lazy" src="https://static.builtin.com/dist/images/skinny_9.svg" width="67"/></a>
# <div class="d-flex"><div class="search" x-data="headerSearch()"><button aria-expanded="false" aria-label="search button" class="btn dropdown-toggle h-100" data-bs-auto-close="outside" data-bs-offset="0,0" data-bs-toggle="dropdown" id="header-search-dropdown" type="button"><i class="fa-solid fa-magnifying-glass fs-2xl text-white"></i></button>
# <div class="dropdown-menu"><div class="input-group mb-md px-md"><span class="input-group-text bg-white"><i class="fa-solid fa-magnifying-glass fs-xl text-midnight"></i></span>
# <input autofocus="" class="form-control border-start-0" id="header-search-input" name="search jobs input" placeholder="Search" type="text" x-model="searchTerm" x-on:input.debounce.500ms="updateJobs" x-on:keydown.enter="goToJobSearch"/></div>
# <div class="bg-gray-01-highlight px-md mb-md"><a :href="jobSearchUrl" x-text="searchTerm + ' In Jobs'"></a></div>
# <template x-for="job in jobs"><a :href="job.alias" class="text-decoration-none"><div class="mb-md"><div class="d-flex align-items-center bg-gray-01 mx-md rounded-1 px-md py-sm"><div class="rounded-circle bg-white h-4xl w-4xl d-flex align-items-center justify-content-center"><img :src="job.logo" alt="Company Photo" class="object-fit-contain" height="42" loading="lazy" width="42"/></div>
# <div class="ms-lg"><div class="text-midnight fw-semibold" x-text="job.title"></div>
# <div class="font-montserrat-button text-uppercase fs-xs" x-text="job.industries"></div></div></div></div></a></template>
# <template x-if="searchTerm.length &gt; 0 &amp;&amp; jobs.length === 0"><a class="text-decoration-none" href="/node/add/company"><div class="border border-gray-02 d-flex gap-lg p-md m-md rounded-1 align-items-center"><div class="bg-gray-01 rounded-circle h-4xl w-4xl d-flex align-items-center justify-content-center"><i class="fa-thin fa-rocket-launch fs-2xl"></i></div>
# <div><div class="fs-xl mb-sm text-midnight fw-semibold">Can't find your company?</div>
# <div class="fs-sm">Create a company profile.</div></div></div></a></template>
# <div class="d-flex justify-content-center"><a class="d-flex align-items-center" href="/jobs">View All Jobs</a></div></div></div>
# <div class="my-auto me-md ms-md d-none d-lg-inline"><a aria-disabled="true" class="btn btn-secondary text-white btn-lg me-md fw-bold fs-sm text-uppercase d-none" href="https://employers.builtin.com/membership?utm_medium=BIReferral&amp;utm_source=foremployers" id="for-employers-button" role="button" target="_blank">
#                         For Employers
#                     </a><a aria-disabled="true" class="btn btn-secondary text-white btn-lg me-md fw-bold fs-sm text-uppercase d-none" href="/node/add/job" id="post-job-button" role="button">
#                     Post Job
#                 </a></div><div class="d-flex" id="logged-out-state"><div class="my-auto"><button class="btn border-0 p-0 text-white fw-bold text-uppercase fs-sm special-link" id="join" type="button">
#                                 Join
#                             </button></div>
# <span class="my-auto h-md mx-sm border border-cyan"></span>
# <div class="my-auto"><button class="btn border-0 p-0 text-white fw-bold text-uppercase fs-sm special-link" id="login" type="button">
#                                 Log In
#                             </button></div></div></div></div></div>
# <nav class="navbar navbar-expand-lg d-none d-lg-block bg-white p-0 border-bottom border-gray-02"><div class="container-fluid"><button class="navbar-toggler" data-bs-target="#main_nav" data-bs-toggle="collapse" type="button"><span class="navbar-toggler-icon"></span></button>
# <div class="collapse navbar-collapse" id="main_nav"><nav class="container" role="navigation"><ul class="navbar-nav d-flex gap-lg" role="menu"><li class="nav-item fs-lg dropdown has-megamenu" role="menuitem"><a builtin-toggle="dropdown" class="nav-link top-nav-item text-nowrap text-app-primary text-uppercase py-md h-3xl font-montserrat-button dropdown-toggle" href="/jobs">Jobs</a><div class="dropdown-menu megamenu"><div class="container visually-hidden" data-js="megamenu-container"><div class="row"><div class="col mb-lg text-uppercase text-gray-03 font-barlow fw-medium fs-xl">Most Popular Jobs</div></div>
# <div class="row"><div class="col"><div aria-labelledby="block-popular-techtopics-menu" class="flex-column small d-flex gap-md" role="menu"><div><a class="nav-link fw-semibold" href="/jobs" role="menuitem">All Tech Jobs</a></div><div><a class="nav-link fw-semibold" href="/jobs/remote" role="menuitem">Remote Tech Jobs</a></div><div><a class="nav-link fw-semibold" href="/jobs/data-analytics" role="menuitem">Data + Analytics</a></div><div><a class="nav-link fw-semibold" href="/jobs/design-ux" role="menuitem">Design + UX</a></div><div><a class="nav-link fw-semibold" href="/jobs/dev-engineering" role="menuitem">Developer + Engineer</a></div></div></div>
# <div class="col"><div aria-labelledby="block-popular-techtopics-menu" class="flex-column small d-flex gap-md" role="menu"><div><a class="nav-link fw-semibold" href="/jobs/finance" role="menuitem">Finance</a></div><div><a class="nav-link fw-semibold" href="/jobs/hr" role="menuitem">HR + Recruiting</a></div><div><a class="nav-link fw-semibold" href="/jobs/legal" role="menuitem">Legal</a></div><div><a class="nav-link fw-semibold" href="/jobs/marketing" role="menuitem">Marketing</a></div><div><a class="nav-link fw-semibold" href="/jobs/operations" role="menuitem">Operations</a></div></div></div>
# <div class="col"><div aria-labelledby="block-popular-techtopics-menu" class="flex-column small d-flex gap-md" role="menu"><div><a class="nav-link fw-semibold" href="/jobs/product" role="menuitem">Product</a></div><div><a class="nav-link fw-semibold" href="/jobs/project-management" role="menuitem">Project Mgmt.</a></div><div><a class="nav-link fw-semibold" href="/jobs/sales" role="menuitem">Sales</a></div></div></div>
# <div class="col"><div><a class="btn btn-primary fw-bold text-uppercase px-3xl fs-sm text-nowrap" href="/jobs">
#                                                         See All Jobs
#                                                         <i class="fa-solid fa-arrow-right fs-xs text-white"></i></a></div></div></div></div></div></li><li class="nav-item fs-lg dropdown has-megamenu" role="menuitem"><a builtin-toggle="dropdown" class="nav-link top-nav-item text-nowrap text-app-primary text-uppercase py-md h-3xl font-montserrat-button dropdown-toggle" href="/companies">Companies</a><div class="dropdown-menu megamenu"><div class="container visually-hidden" data-js="megamenu-container"><div class="row"><div class="col mb-lg text-uppercase text-gray-03 font-barlow fw-medium fs-xl">Most Popular Searches</div></div>
# <div class="row"><div class="col"><div aria-labelledby="block-popular-techtopics-menu" class="flex-column small d-flex gap-md" role="menu"><div><a class="nav-link fw-semibold" href="/companies" role="menuitem">All Companies</a></div><div><a class="nav-link fw-semibold" href="/companies/type/artificial-intelligence-companies" role="menuitem">A.I. Companies</a></div></div></div>
# <div class="col"><div aria-labelledby="block-popular-techtopics-menu" class="flex-column small d-flex gap-md" role="menu"><div><a class="nav-link fw-semibold" href="/awards/us/2024/best-places-to-work" role="menuitem">Best Places to Work</a></div><div><a class="nav-link fw-semibold" href="/companies/type/fintech-companies" role="menuitem">Fintech Companies</a></div></div></div>
# <div class="col"><div aria-labelledby="block-popular-techtopics-menu" class="flex-column small d-flex gap-md" role="menu"><div><a class="nav-link fw-semibold" href="/companies/location/fully-remote" role="menuitem">Fully Remote Companies</a></div></div></div>
# <div class="col"><div><a class="btn btn-primary fw-bold text-uppercase px-3xl fs-sm text-nowrap" href="/companies">
#                                                         See All Companies
#                                                         <i class="fa-solid fa-arrow-right fs-xs text-white"></i></a></div></div></div></div></div></li><li class="nav-item fs-lg dropdown has-megamenu" role="menuitem"><a builtin-toggle="dropdown" class="nav-link top-nav-item text-nowrap text-app-primary text-uppercase py-md h-3xl font-montserrat-button dropdown-toggle" href="/tech-topics">Articles</a><div class="dropdown-menu megamenu"><div class="container visually-hidden" data-js="megamenu-container"><div class="row"><div class="col mb-lg text-uppercase text-gray-03 font-barlow fw-medium fs-xl">Most Popular Tech Topics</div></div>
# <div class="row"><div class="col"><div aria-labelledby="block-popular-techtopics-menu" class="flex-column small d-flex gap-md" role="menu"><div><a class="nav-link fw-semibold" href="/artificial-intelligence" role="menuitem">Artificial Intelligence</a></div><div><a class="nav-link fw-semibold" href="/blockchain" role="menuitem">Blockchain</a></div><div><a class="nav-link fw-semibold" href="/cloud-computing" role="menuitem">Cloud Computing</a></div><div><a class="nav-link fw-semibold" href="/cybersecurity" role="menuitem">Cyber Security</a></div><div><a class="nav-link fw-semibold" href="/data-science" role="menuitem">Data Science</a></div></div></div>
# <div class="col"><div aria-labelledby="block-popular-techtopics-menu" class="flex-column small d-flex gap-md" role="menu"><div><a class="nav-link fw-semibold" href="/edtech" role="menuitem">Edtech</a></div><div><a class="nav-link fw-semibold" href="/expert-contributors" role="menuitem">Expert Contributors</a></div><div><a class="nav-link fw-semibold" href="/fintech" role="menuitem">Fintech</a></div><div><a class="nav-link fw-semibold" href="/hardware" role="menuitem">Hardware</a></div><div><a class="nav-link fw-semibold" href="/healthcare-technology" role="menuitem">Healthcare Technology</a></div></div></div>
# <div class="col"><div aria-labelledby="block-popular-techtopics-menu" class="flex-column small d-flex gap-md" role="menu"><div><a class="nav-link fw-semibold" href="/internet-things" role="menuitem">IoT: The Internet of Things</a></div><div><a class="nav-link fw-semibold" href="/remote-work" role="menuitem">Remote Work</a></div><div><a class="nav-link fw-semibold" href="/robotics" role="menuitem">Robotics</a></div><div><a class="nav-link fw-semibold" href="/transportation-tech" role="menuitem">Transportation Tech</a></div><div><a class="nav-link fw-semibold" href="/software-engineering-perspectives" role="menuitem">Software Engineering</a></div></div></div>
# <div class="col"><div><a class="btn btn-primary fw-bold text-uppercase px-3xl fs-sm text-nowrap" href="/tech-topics">
#                                                         See All Articles
#                                                         <i class="fa-solid fa-arrow-right fs-xs text-white"></i></a></div></div></div></div></div></li><li class="nav-item fs-lg dropdown has-megamenu" role="menuitem"><a builtin-toggle="dropdown" class="nav-link top-nav-item text-nowrap text-app-primary text-uppercase py-md h-3xl font-montserrat-button dropdown-toggle" href="/salaries">Salaries</a><div class="dropdown-menu megamenu"><div class="container visually-hidden" data-js="megamenu-container"><div class="row"><div class="col mb-lg text-uppercase text-gray-03 font-barlow fw-medium fs-xl">Most Popular Salaries</div></div>
# <div class="row"><div class="col"><div aria-labelledby="block-popular-techtopics-menu" class="flex-column small d-flex gap-md" role="menu"><div><a class="nav-link fw-semibold" href="/salaries/sales/account-executive" role="menuitem">Account Executive</a></div><div><a class="nav-link fw-semibold" href="/salaries/sales/account-manager" role="menuitem">Account Manager</a></div><div><a class="nav-link fw-semibold" href="/salaries/data-analytics/data-scientist" role="menuitem">Data Scientist</a></div><div><a class="nav-link fw-semibold" href="/salaries/dev-engineer/front-end-developer" role="menuitem">Front End Developer</a></div></div></div>
# <div class="col"><div aria-labelledby="block-popular-techtopics-menu" class="flex-column small d-flex gap-md" role="menu"><div><a class="nav-link fw-semibold" href="/salaries/hr-recruiting/hr-manager" role="menuitem">HR Manager</a></div><div><a class="nav-link fw-semibold" href="/salaries/marketing/marketing-manager" role="menuitem">Marketing Manager</a></div><div><a class="nav-link fw-semibold" href="/salaries/operations/operations-manager" role="menuitem">Operations Manager</a></div><div><a class="nav-link fw-semibold" href="/salaries/design-ux/product-designer" role="menuitem">Product Designer</a></div></div></div>
# <div class="col"><div aria-labelledby="block-popular-techtopics-menu" class="flex-column small d-flex gap-md" role="menu"><div><a class="nav-link fw-semibold" href="/salaries/product/product-manager" role="menuitem">Product Manager</a></div><div><a class="nav-link fw-semibold" href="/salaries/project-mgmt/project-manager" role="menuitem">Project Manager</a></div><div><a class="nav-link fw-semibold" href="/salaries/dev-engineer/software-engineer" role="menuitem">Software Engineer</a></div><div><a class="nav-link fw-semibold" href="/salaries/design-ux/ux-designer" role="menuitem">UX Designer</a></div></div></div>
# <div class="col"><div><a class="btn btn-primary fw-bold text-uppercase px-3xl fs-sm text-nowrap" href="/salaries">
#                                                         See All Salaries
#                                                         <i class="fa-solid fa-arrow-right fs-xs text-white"></i></a></div></div></div></div></div></li><li class="nav-item fs-lg" role="menuitem"><a builtin-toggle="dropdown" class="nav-link top-nav-item text-nowrap text-app-primary text-uppercase py-md h-3xl font-montserrat-button" href="/learn">Courses</a></li><li class="nav-item fs-lg ms-auto h-3xl underline-title" role="menuitem"><div class="nav-link d-flex align-items-center top-nav-item text-nowrap text-app-primary text-uppercase py-md h-3xl fw-bold"><a class="nav-link top-nav-item text-nowrap text-app-primary text-uppercase py-md h-3xl fw-bold fs-sm" href="/login?destination=/home/jobs/saved"><i class="fa-solid fa-heart fs-md text-pink me-sm"></i>
#                                     My items
#                                 </a></div></li></ul></nav></div></div></nav>
# </header>
# <div>
# <main class="bg-gray-01" role="main">
# <div class="job-board" x-data="jobBoard">
# <div class="job-board-filters gradient-blueberry position-relative">
# <div class="container py-md py-md-lg">
# <div class="font-barlow fw-medium fs-2xl text-white mb-md d-none d-md-block">Get the job you really want</div>
# <div class="d-flex flex-column flex-lg-row gap-sm mb-lg">
# <div class="dropdown fill-even position-relative job-search-dropdown" x-ref="jobSearchDropdownContainer"><div class="d-flex align-items-center bg-white position-relative form-floating fill-even search-input-container rounded-2" x-ref="jobSearchTrigger"><input @blur="onJobSearchBlur()" @focus="getJobTitles()" aria-describedby="search" autofocus="" class="flex-grow-1 border-0 pe-2xl form-control" id="searchJobsInput" placeholder="Job Title or Keyword" type="text" x-model="jobSearchTerm" x-on:input.debounce="getJobTitles" x-on:keydown.arrow-down.prevent="nextJobTitle()" x-on:keydown.arrow-up.prevent="previousJobTitle()" x-on:keyup.enter="selectJobTitle(selectedJobTitleIndex &gt;= 0 ? availableJobTitleOptions[selectedJobTitleIndex] : jobSearchTerm)" x-ref="searchJobsInput"/>
# <label for="searchJobsInput">Job Title or Keyword</label>
# <div @click="clearSearch()" class="position-absolute d-flex align-items-center justify-content-center h-2xl w-2xl" style="right:3rem;" type="button" x-show.important="jobSearchTerm.length &gt; 0"><i class="fa-solid fa-xmark fs-sm"></i></div>
# <button @click="updateJobs()" aria-label="Search Jobs" class="btn btn-dark h-2xl w-2xl me-sm" name="Search Jobs" type="button"><i class="fa-solid fa-magnifying-glass fs-sm text-white"></i></button></div>
# <ul class="dropdown-menu p-0 w-100"><div class="list-group"><template x-if="availableJobTitleOptions.length &gt; 0"><template :key="jobTitle" x-for="(jobTitle,index) in availableJobTitleOptions"><label :class="{'active' : index === selectedJobTitleIndex}" :id="'jobSearchTitle-' + jobTitle" class="list-group-item list-group-item-action text-truncate" x-on:click.stop="selectJobTitle(jobTitle)"><div type="button" x-text="jobTitle"></div></label></template></template></div></ul></div>
# <div class="dropdown fill-even" id="remotePreference-dropdown"><button aria-expanded="false" class="d-flex form-control fw-semibold dropdown-toggle h-100 align-items-center justify-content-between" data-bs-auto-close="outside" data-bs-toggle="dropdown" id="remotePreferenceDropdownButton" type="button"><div :class="selectedRemotePreferenceIds.length &gt; 0 ? 'text-gray-04' : 'text-gray-03'"><i class="fa-solid fa-signal-stream me-sm"></i>
# <span x-text="remotePreferenceDisplayText">Remote / Hybrid</span></div></button>
# <div aria-labelledby="remotePreferenceDropdownMenu" class="dropdown-menu p-0 w-100"><div class="list-group"><template :key="remotePreferenceFilter.id" x-for="remotePreferenceFilter in remotePreferenceFilterOptions"><label class="list-group-item list-group-item-action text-nowrap"><input :id="'remotePreference-' + remotePreferenceFilter.id" :value="remotePreferenceFilter.id" @change="updateJobs()" class="form-check-input" type="checkbox" x-model.number="selectedRemotePreferenceIds"/>
# <span class="form-check-label text-nowrap" x-text="remotePreferenceFilter.name"></span></label></template></div>
# <div class="d-flex justify-content-between sticky-bottom border-top py-sm px-xs bg-white"><button @click="resetSelectedRemotePreferences();updateJobs()" class="btn btn-lg font-montserrat-button text-uppercase text-gray-03 d-inline-block" type="button">Clear</button>
# <button @click="document.getElementById('remotePreferenceDropdownButton').click()" class="btn btn-primary btn-lg font-montserrat-button text-uppercase text-white d-inline-block" type="button">Apply</button></div></div></div>
# <div class="dropdown fill-even" id="location-dropdown"><div class="dropdown w-100" x-data="locationDropdownJobBoard" x-ref="locationDropdownContainer-JobBoard"><div class="form-floating" x-ref="locationDropdownTrigger-JobBoard"><input :class="{'is-invalid': isLocationValid === undefined ? false : !isLocationValid}" :disabled="gettingLocation" @blur="onLocationSearchBlur()" @focus="searchLocations()" autocomplete="off" class="form-control pe-2xl" id="locationDropdownInput" name="location" placeholder="Select Location" style="background-image: none !important;" type="text" x-model="locationSearchTerm" x-on:input.debounce="searchLocations(); resetOnEmpty();" x-on:keydown.arrow-down.prevent="nextLocation()" x-on:keydown.arrow-up.prevent="previousLocation()" x-on:keyup.enter="selectLocation(selectedLocationIndex &gt;= 0 ? searchedLocationResults[selectedLocationIndex] : null)" x-ref="locationDropdownInput-JobBoard">
# <label for="locationDropdownInput">Location</label><button @click="setToCurrentLocation()" aria-label="Use Current Location" class="btn fs-xs text-primary position-absolute p-0 current-location-button-icon-only" type="button"><i class="fa-solid fs-xl fa-location-crosshairs"></i></button></input></div>
# <ul aria-labelledby="profileLocation" class="dropdown-menu p-0 w-100" x-ref="locationDropdownMenu"><div class="list-group"><template x-if="searchedLocationResults.length &gt; 0"><template :key="location.placeId" x-for="(location,index) in searchedLocationResults"><label :class="{'active' : index === selectedLocationIndex}" @click="selectLocation(location)" class="list-group-item list-group-item-action border-0 text-truncate"><div :id="'location-' + location.placeId" type="button" x-text="location.text"></div></label></template></template>
# <template x-if="searchedLocationResults.length === 0 &amp;&amp; locationSearchTerm.length &gt; 0"><div class="list-group-item text-nowrap">No Results Found</div></template></div></ul></div></div>
# </div>
# <div class="d-flex align-items-center gap-sm" id="lower-filters">
# <template x-if="isSkillsFilterVisible">
# <div class="dropdown d-none d-lg-block" id="skill-dropdown"><button :class="{'selected-item' : selectedSkills.length &gt; 0}" aria-expanded="false" class="btn btn-outline-light rounded-4 fw-semibold fs-sm dropdown-toggle" data-bs-auto-close="outside" data-bs-toggle="dropdown" id="skillDropdownButton" type="button"><template x-if="selectedSkills.length === 0"><span class="h-sm w-sm rounded-circle bg-mint d-inline-block me-xs"></span></template>
# <span>Skills</span></button>
# <div aria-labelledby="skillDropdownMenu" class="dropdown-menu p-0 w-100"><div class="d-flex sticky-top border-bottom p-xs fill-even bg-white"><div class="d-flex align-items-center justify-content-center h-2xl w-2xl"><i class="fa-solid fa-magnifying-glass fs-lg"></i></div>
# <input aria-describedby="search" class="flex-grow-1 form-control border-0" placeholder="Type to filter..." type="text" x-model="skillsSearchTerm"/></div>
# <template x-if="visibleSkillFilterOptions.length &gt; 0"><div class="list-group"><template :key="skillItem.skill" x-for="skillItem in visibleSkillFilterOptions"><label class="list-group-item list-group-item-action text-nowrap"><input :id="'skill-' + skillItem.skill" :value="skillItem.skill" @change="updateJobs()" class="form-check-input" type="checkbox" x-model="selectedSkills"/>
# <span class="form-check-label text-nowrap" x-text="skillItem.skill + ' (' + skillItem.count + ')'"></span></label></template></div></template>
# <template x-if="visibleSkillFilterOptions.length === 0"><div class="d-flex align-items-center justify-content-center py-lg"><span>No Results</span></div></template>
# <div class="d-flex justify-content-between sticky-bottom border-top py-sm px-xs bg-white"><button @click="resetSelectedSkills();updateJobs()" class="btn btn-lg font-montserrat-button text-uppercase text-gray-03 d-inline-block" type="button">Clear</button>
# <button @click="document.getElementById('skillDropdownButton').click()" class="btn btn-primary btn-lg font-montserrat-button text-uppercase text-white d-inline-block" type="button">Apply</button></div></div></div>
# </template>
# <div class="dropdown d-none d-lg-block" id="postedDate-dropdown" x-ref="postedDateDropdownContainer"><button :class="{'selected-item' : selectedDaysSinceUpdated !== null}" aria-expanded="false" class="btn btn-outline-light rounded-4 fw-semibold fs-sm" data-bs-auto-close="outside" data-bs-toggle="dropdown" id="postedDateDropdownButton" type="button" x-ref="postedDateDropdownButton"><span>Date Posted</span>
# <i :class="selectedDaysSinceUpdated !== null ? 'text-pretty-blue' : 'text-white'" class="fa-solid fa-bars-sort fs-sm"></i></button>
# <div aria-labelledby="postedDateDropdownMenu" class="dropdown-menu p-0 w-100" id="postedDate-dropdown-menu"><div class="list-group"><template :key="postedDate.id" x-for="postedDate in postedDateFilterOptions"><div class="d-flex align-items-center"><label class="list-group-item list-group-item-action text-nowrap"><input :id="'postedDate-' + postedDate.id" :value="postedDate.filterValue" @change="updateJobs()" @click="uncheckPostedDateRadio(postedDate.filterValue)" class="form-check-input" name="postedDateRadios" type="radio" x-model.number="selectedDaysSinceUpdated"/>
# <span class="form-check-label text-nowrap" x-text="postedDate.name"></span></label></div></template></div>
# <div class="d-flex justify-content-between sticky-bottom border-top py-sm px-xs bg-white"><button @click="resetSelectedPostedDate();updateJobs()" class="btn btn-lg font-montserrat-button text-uppercase text-gray-03 d-inline-block" type="button">Clear</button>
# <button @click="document.getElementById('postedDateDropdownButton').click()" class="btn btn-primary btn-lg font-montserrat-button text-uppercase text-white d-inline-block" type="button">Apply</button></div></div></div>
# <button :class="{'early-applicant-selected': earlyApplicant}" @click="earlyApplicant = !earlyApplicant; updateJobs()" class="btn btn-outline-light rounded-4 fw-semibold fs-sm d-none d-lg-block" id="earlyApplicantButton" type="button">
#                     Early Applicant
#                 </button>
# <div :class="!isSkillsFilterVisible ? 'd-lg-block' : 'd-xl-block'" class="dropdown d-none" id="category-dropdown"><button :class="{'selected-item' : selectedCategoryId !== null}" aria-expanded="false" class="btn btn-outline-light rounded-4 fw-semibold fs-sm dropdown-toggle" data-bs-auto-close="outside" data-bs-toggle="dropdown" id="categoryDropdownButton" type="button">
#         Job Category
#     </button>
# <div aria-labelledby="categoryDropdownMenu" class="dropdown-menu p-0 w-100"><div class="list-group"><template :key="category.id" x-for="category in categoryFilterOptions"><div><div class="d-flex align-items-center"><label :class="{'collapsible-item' : subCategoryFilterOptions[category.id]}" class="list-group-item list-group-item-action text-nowrap"><input :id="'category-' + category.id" :value="category.id" @change="updateCategories()" @click="uncheckCategoryRadio(category.id)" class="form-check-input" name="jobCategoryRadios" type="radio" x-model.number="selectedCategoryId"/>
# <span class="form-check-label text-nowrap" x-text="category.name"></span></label>
# <template x-if="subCategoryFilterOptions[category.id]"><div @click="toggleCategory(category.id)" class="d-flex align-items-center justify-content-center w-xl" type="button"><i class="fa-solid fa-caret-down" x-show="category.collapsed"></i>
# <i class="fa-solid fa-caret-up" x-show="!category.collapsed"></i></div></template></div>
# <template x-if="!category.collapsed"><template :key="subCategory.id" x-for="subCategory in subCategoryFilterOptions[category.id]"><div class="ps-lg"><label class="list-group-item list-group-item-action text-nowrap"><input :id="'subCategory-' + subCategory.id" :value="subCategory.id" @change="updateSubCategories(category.id)" class="form-check-input" type="checkbox" x-model.number="selectedSubCategoryIds"/>
# <span class="form-check-label text-nowrap" x-text="subCategory.name"></span></label></div></template></template></div></template></div>
# <div class="d-flex justify-content-between sticky-bottom border-top py-sm px-xs bg-white"><button @click="resetSelectedCategories();updateJobs()" class="btn btn-lg font-montserrat-button text-uppercase text-gray-03 d-inline-block" type="button">Clear</button>
# <button @click="document.getElementById('categoryDropdownButton').click()" class="btn btn-primary btn-lg font-montserrat-button text-uppercase text-white d-inline-block" type="button">Apply</button></div></div></div>
# <template x-if="!isSkillsFilterVisible">
# <div class="dropdown d-none d-xl-block" id="experience-dropdown"><button :class="{'selected-item' : selectedExperienceFilterValues.length &gt; 0}" aria-expanded="false" class="btn btn-outline-light rounded-4 fw-semibold fs-sm dropdown-toggle" data-bs-auto-close="outside" data-bs-toggle="dropdown" id="experienceDropdownButton" type="button">
#         Experience
#     </button>
# <div aria-labelledby="experienceDropdownMenu" class="dropdown-menu p-0 w-100"><div class="list-group"><template :key="experience.id" x-for="experience in experiencesFilterOptions.slice(0, -1)"><label class="list-group-item list-group-item-action text-nowrap"><input :id="'experience-' + experience.id" :value="experience.filterValue" @change="updateJobs()" class="form-check-input" type="checkbox" x-model="selectedExperienceFilterValues"/>
# <span class="form-check-label text-nowrap" x-text="experience.name"></span></label></template></div>
# <div class="d-flex justify-content-between sticky-bottom border-top py-sm px-xs bg-white"><button @click="resetSelectedExperiences();updateJobs()" class="btn btn-lg font-montserrat-button text-uppercase text-gray-03 d-inline-block" type="button">Clear</button>
# <button @click="document.getElementById('experienceDropdownButton').click()" class="btn btn-primary btn-lg font-montserrat-button text-uppercase text-white d-inline-block" type="button">Apply</button></div></div></div>
# </template>
# <div class="dropdown d-none d-xl-block" id="industry-dropdown"><button :class="{'selected-item' : selectedIndustryIds.length &gt; 0}" aria-expanded="false" class="btn btn-outline-light rounded-4 fw-semibold fs-sm dropdown-toggle" data-bs-auto-close="outside" data-bs-toggle="dropdown" id="industryDropdownButton" type="button">
#         Industry
#     </button>
# <div aria-labelledby="industryDropdownMenu" class="dropdown-menu p-0 w-100"><div class="d-flex sticky-top border-bottom p-xs fill-even bg-white"><div class="d-flex align-items-center justify-content-center h-2xl w-2xl"><i class="fa-solid fa-magnifying-glass fs-lg"></i></div>
# <input aria-describedby="search" class="flex-grow-1 form-control border-0" placeholder="Type to filter..." type="text" x-model="industrySearchTerm"/></div>
# <template x-if="visibleIndustryFilterOptions.length &gt; 0"><div class="list-group"><template :key="industry.id" x-for="industry in visibleIndustryFilterOptions"><label class="list-group-item list-group-item-action text-nowrap"><input :id="'industry-' + industry.id" :value="industry.id" @change="updateJobs()" class="form-check-input" type="checkbox" x-model.number="selectedIndustryIds"/>
# <span class="form-check-label text-nowrap" x-text="industry.name"></span></label></template></div></template>
# <template x-if="visibleIndustryFilterOptions.length === 0"><div class="d-flex align-items-center justify-content-center py-lg"><span>No Results</span></div></template>
# <div class="d-flex justify-content-between sticky-bottom border-top py-sm px-xs bg-white"><button @click="resetSelectedIndustries();updateJobs()" class="btn btn-lg font-montserrat-button text-uppercase text-gray-03 d-inline-block" type="button">Clear</button>
# <button @click="document.getElementById('industryDropdownButton').click()" class="btn btn-primary btn-lg font-montserrat-button text-uppercase text-white d-inline-block" type="button">Apply</button></div></div></div>
# <div x-show="!hideSearchArea">
# <div class="dropdown d-none d-lg-block" id="searcharea-dropdown" x-ref="searchAreaDropdownContainer"><button :class="{'selected-item' : selectedSearchAreaId &gt; 0}" @click="searchAreaDropdown.toggle()" aria-expanded="false" class="btn btn-outline-light rounded-4 fw-semibold fs-sm dropdown-toggle" id="searchAreaDropdownButton" type="button" x-ref="searchAreaDropdownButton"><span x-text="searchAreaDisplayText">Search Area</span></button>
# <div aria-labelledby="searchAreaDropdownMenu" class="dropdown-menu p-0 w-100" id="searcharea-dropdown-menu"><div class="list-group"><template :key="searchArea.id" x-for="searchArea in searchAreaFilterOptions"><div class="d-flex align-items-center"><label class="list-group-item list-group-item-action text-nowrap"><input :id="'searchArea-' + searchArea.id" :value="searchArea.id" @change="updateJobs()" @click="uncheckSearchAreaRadioDynamic(searchArea.id)" class="form-check-input" name="searchAreaRadios" type="radio" x-model.number="selectedSearchAreaId"/>
# <span class="form-check-label text-nowrap" x-text="searchArea.name"></span></label></div></template></div>
# <div class="d-flex justify-content-between sticky-bottom border-top py-sm px-xs bg-white"><button @click="resetSelectedSearchArea();updateJobs()" class="btn btn-lg font-montserrat-button text-uppercase text-gray-03 d-inline-block" type="button">Clear</button>
# <button @click="document.getElementById('searchAreaDropdownButton').click()" class="btn btn-primary btn-lg font-montserrat-button text-uppercase text-white d-inline-block" type="button">Apply</button></div></div></div>
# </div>
# <div class="d-none d-lg-block bg-white h-xl" style="width: 1.5px"></div>
# <button aria-controls="offcanvasRight" aria-expanded="false" class="flex-grow-1 flex-lg-grow-0 btn btn-outline-light rounded-4 fw-semibold fs-sm filter-button" data-bs-target="#allFiltersOffcanvas" data-bs-toggle="offcanvas" type="button">
# <span>All Filters</span>
# <i class="fa-regular fa-sliders-simple"></i>
# </button>
# <button @click="resetAllFilters()" class="btn d-none d-lg-block text-white d-inline-block fw-semibold fs-sm rounded-4 reset-button p-xs" type="button">Reset</button>
# </div>
# </div>
# <div class="left-image"></div>
# <div class="top-right-image"></div>
# <div class="bottom-right-image"></div>
# </div>
# <div>
# <div id="jobs-list">
# <div class="container">
# <div class="row">
# <div class="d-flex flex-column flex-md-row justify-content-between text-black my-sm my-md-md align-items-start align-items-md-center gap-0 gap-md-sm">
# <h1 class="font-barlow fw-medium fs-xl m-0">Top Tech Jobs &amp; Startup Jobs</h1>
# <div class="text-uppercase font-barlow fs-sm">
# <span class="fw-bold">10,000+</span>
# <span> Job Results</span>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="mb-sm" id="search-results-top">
# <div class="d-flex gap-sm flex-column"><div class="position-relative job-bounded-responsive border rounded-3 border-gray-02 position-relative bg-white p-md" data-id="job-card" id="job-card-3680837"><div class="row" id="main"><div class="col-12 col-lg-6"><a class="mb-sm d-inline-flex align-items-center text-pretty-blue link-visited-color z-1" href="/company/northwestern-mutual" type="button"><picture class="d-inline-block"><img alt="Northwestern Mutual Logo" class="p-xs rounded-2 border border-gray-02 me-md min-h-3xl object-fit-contain" data-builtin-track-job-id="3680837" data-id="company-img" height="48" loading="lazy" src="https://cdn.builtin.com/cdn-cgi/image/f=auto,fit=scale-down,w=40,h=40/https://builtin.com/sites/www.builtin.com/files/2021-08/Northwestern Mutual .jpeg" width="48"/></picture>
# <div class="font-barlow fs-md fs-xl-xl d-inline-block m-0 hover-underline" data-builtin-track-job-id="3680837" data-id="company-title"><span>Northwestern Mutual</span></div></a>
# <h2 class="fw-extrabold fs-md fs-xl-xl"><a class="card-alias-after-overlay hover-underline link-visited-color text-break" href="/job/investment-analyst-intern-private-debt-equity-summer-2025/2451111" target="_blank">Investment Analyst Intern - Private Debt &amp; Equity, Summer 2025</a></h2></div>
# <div class="col-12 col-lg-6 bounded-attribute-section d-flex align-items-start align-items-lg-center fs-md flex-column flex-lg-row"><div class="d-flex flex-grow-1 gap-lg"><div class="d-flex flex-column gap-0 flex-md-row gap-md-md flex-lg-column gap-lg-0 fill-even"><div class="d-flex align-items-start gap-sm"><div class="d-flex justify-content-center align-items-center h-lg min-w-md"><i class="fa-regular fa-clock fs-xs text-pretty-blue"></i></div>
# <span class="font-barlow text-gray-03">An Hour Ago</span></div><div class="d-flex align-items-start gap-sm"><div class="d-flex justify-content-center align-items-center h-lg min-w-md"><i class="fa-regular fa-location-dot fs-xs text-pretty-blue"></i></div>
# <div><span class="font-barlow text-gray-03">Milwaukee, WI</span></div></div><div class="d-flex gap-md"><div class="d-flex align-items-start gap-sm"><div class="d-flex justify-content-center align-items-center h-lg min-w-md"><i class="fa-regular fa-house-building fs-xs text-pretty-blue"></i></div>
# <span class="font-barlow text-gray-03">Hybrid</span></div></div></div><div class="d-none d-xl-block fill-even"><div class="d-flex align-items-start gap-sm"><div class="d-flex justify-content-center align-items-center h-lg min-w-md"><i class="fa-regular fa-user-group fs-xs text-pretty-blue"></i></div>
# <span class="font-barlow text-gray-03">8,400 Employees</span></div><div class="d-flex align-items-start gap-sm"><div class="d-flex justify-content-center align-items-center h-lg min-w-md"><i class="fa-regular fa-trophy fs-xs text-pretty-blue"></i></div>
# <span class="font-barlow text-gray-03">1 Years of Experience</span></div></div></div>
# <div class="align-items-end justify-content-between h-100 d-flex flex-row flex-lg-column w-100 w-lg-auto gap-md gap-lg-0"><div class="d-none d-lg-block"></div>
# <a class="btn btn-lg btn-outline-primary text-nowrap mt-sm flex-grow-1 flex-lg-grow-0 z-1" data-alias="/job/investment-analyst-intern-private-debt-equity-summer-2025/2451111" data-builtin-track-job-id="3680837" data-id="view-job-button" href="/job/investment-analyst-intern-private-debt-equity-summer-2025/2451111" target="_blank"><span>Apply</span></a>
# <div class="d-flex z-1"><my-item class="h-2xl mt-xs p-sm w-2xl fs-2xl" entity-id="3680837" entity-type="job"></my-item><button aria-label="Collapse Button" class="btn btn-link text-decoration-none d-flex justify-content-end h-2xl w-2xl align-items-center justify-content-center mt-xs collapsed fs-2xl" data-bs-target="#drop-data-3680837" data-bs-toggle="collapse" data-id="job-dropdown-button" id="job-dropdown-button" type="button"><i class="fa-solid fa-angles-down text-gray-03 d-none" data-id="job-dropdown-button"></i>
# <i class="fa-solid fa-angles-up text-gray-03 d-block" data-id="job-dropdown-button"></i></button></div></div></div></div>
# <div class="collapse" data-job-id="3680837" id="drop-data-3680837"><div class="pt-md border-top border-gray-02 mt-md mt-lg-lg"><div class="d-flex flex-column flex-md-row gap-sm d-xl-none mb-md"><div class="d-flex align-items-center"><div class="w-md d-flex justify-content-center align-items-center me-sm"><i class="fa-regular fa-user-group fs-xs text-pretty-blue"></i></div>
# <span class="font-barlow text-gray-03">8,400 Employees</span></div><div class="d-flex align-items-center"><div class="w-md d-flex justify-content-center align-items-center me-sm"><i class="fa-regular fa-trophy fs-xs text-pretty-blue"></i></div>
# <span class="font-barlow text-gray-03">1 Years of Experience</span></div></div><div class="font-barlow fw-medium mb-md">Fintech • Insurance • Financial Services</div><div class="fs-xs fw-regular mb-md">Northwestern Mutual is offering a summer internship for Investment Analysts in Private Debt and Equity. Interns will gain hands-on experience in evaluating investment opportunities, developing financial models, and presenting investment opportunities. The role requires a Bachelor's degree in Finance, Accounting, Economics, or related field with a GPA of 3.5 or higher. Preferred skills include previous internship experience in Private Debt &amp; Equity, financial modeling skills, and strong communication and analytical abilities.</div><div class="border border-2 border-gray-01 rounded-3 px-lg py-md"><div class="d-flex align-items-start align-items-md-center flex-column flex-md-row gap-sm gap-md-md"><div class="font-barlow-overline fs-md text-uppercase text-gray-04">Top Benefits:</div><div class="font-barlow fs-md text-gray-03">401-K</div><div class="font-barlow fs-md text-gray-03">Adoption Assistance</div><div class="font-barlow fs-md text-gray-03">Commuter Benefits</div><div class="font-barlow-overline fs-md text-uppercase text-gray-04">+41 More</div></div></div></div></div></div><div class="position-relative job-bounded-responsive border rounded-3 border-gray-02 position-relative bg-white p-md" data-id="job-card" id="job-card-3680835"><div class="row" id="main"><div class="col-12 col-lg-6"><a class="mb-sm d-inline-flex align-items-center text-pretty-blue link-visited-color z-1" href="/company/northwestern-mutual" type="button"><picture class="d-inline-block"><img alt="Northwestern Mutual Logo" class="p-xs rounded-2 border border-gray-02 me-md min-h-3xl object-fit-contain" data-builtin-track-job-id="3680835" data-id="company-img" height="48" loading="lazy" src="https://cdn.builtin.com/cdn-cgi/image/f=auto,fit=scale-down,w=40,h=40/https://builtin.com/sites/www.builtin.com/files/2021-08/Northwestern Mutual .jpeg" width="48"/></picture>
# <div class="font-barlow fs-md fs-xl-xl d-inline-block m-0 hover-underline" data-builtin-track-job-id="3680835" data-id="company-title"><span>Northwestern Mutual</span></div></a>
# <h2 class="fw-extrabold fs-md fs-xl-xl"><a class="card-alias-after-overlay hover-underline link-visited-color text-break" href="/job/technical-business-analyst-iii-digital-product-billing-payments/2451109" target="_blank">Technical Business Analyst III - Digital Product - Billing &amp; Payments</a></h2></div>
# <div class="col-12 col-lg-6 bounded-attribute-section d-flex align-items-start align-items-lg-center fs-md flex-column flex-lg-row"><div class="d-flex flex-grow-1 gap-lg"><div class="d-flex flex-column gap-0 flex-md-row gap-md-md flex-lg-column gap-lg-0 fill-even"><div class="d-flex align-items-start gap-sm"><div class="d-flex justify-content-center align-items-center h-lg min-w-md"><i class="fa-regular fa-clock fs-xs text-pretty-blue"></i></div>
# <span class="font-barlow text-gray-03">An Hour Ago</span></div><div class="d-flex align-items-start gap-sm"><div class="d-flex justify-content-center align-items-center h-lg min-w-md"><i class="fa-regular fa-location-dot fs-xs text-pretty-blue"></i></div>
# <div><span class="font-barlow text-gray-03">Franklin, WI</span></div></div><div class="d-flex gap-md"><div class="d-flex align-items-start gap-sm"><div class="d-flex justify-content-center align-items-center h-lg min-w-md"><i class="fa-regular fa-house-building fs-xs text-pretty-blue"></i></div>
# <span class="font-barlow text-gray-03">Hybrid</span></div></div></div><div class="d-none d-xl-block fill-even"><div class="d-flex align-items-start gap-sm"><div class="d-flex justify-content-center align-items-center h-lg min-w-md"><i class="fa-regular fa-user-group fs-xs text-pretty-blue"></i></div>
# <span class="font-barlow text-gray-03">8,400 Employees</span></div><div class="d-flex align-items-start gap-sm"><div class="d-flex justify-content-center align-items-center h-lg min-w-md"><i class="fa-regular fa-sack-dollar fs-xs text-pretty-blue"></i></div>
# <span class="font-barlow text-gray-03">64K-118K Annually</span></div><div class="d-flex align-items-start gap-sm"><div class="d-flex justify-content-center align-items-center h-lg min-w-md"><i class="fa-regular fa-trophy fs-xs text-pretty-blue"></i></div>
# <span class="font-barlow text-gray-03">3-5 Years of Experience</span></div></div></div>
# <div class="align-items-end justify-content-between h-100 d-flex flex-row flex-lg-column w-100 w-lg-auto gap-md gap-lg-0"><div class="d-none d-lg-block"></div>
# <a class="btn btn-lg btn-outline-primary text-nowrap mt-sm flex-grow-1 flex-lg-grow-0 z-1" data-alias="/job/technical-business-analyst-iii-digital-product-billing-payments/2451109" data-builtin-track-job-id="3680835" data-id="view-job-button" href="/job/technical-business-analyst-iii-digital-product-billing-payments/2451109" target="_blank"><span>Apply</span></a>
# <div class="d-flex z-1"><my-item class="h-2xl mt-xs p-sm w-2xl fs-2xl" entity-id="3680835" entity-type="job"></my-item><button aria-label="Collapse Button" class="btn btn-link text-decoration-none d-flex justify-content-end h-2xl w-2xl align-items-center justify-content-center mt-xs collapsed fs-2xl" data-bs-target="#drop-data-3680835" data-bs-toggle="collapse" data-id="job-dropdown-button" id="job-dropdown-button" type="button"><i class="fa-solid fa-angles-down text-gray-03 d-none" data-id="job-dropdown-button"></i>
# <i class="fa-solid fa-angles-up text-gray-03 d-block" data-id="job-dropdown-button"></i></button></div></div></div></div>
# <div class="collapse" data-job-id="3680835" id="drop-data-3680835"><div class="pt-md border-top border-gray-02 mt-md mt-lg-lg"><div class="d-flex flex-column flex-md-row gap-sm d-xl-none mb-md"><div class="d-flex align-items-center"><div class="w-md d-flex justify-content-center align-items-center me-sm"><i class="fa-regular fa-user-group fs-xs text-pretty-blue"></i></div>
# <span class="font-barlow text-gray-03">8,400 Employees</span></div><div class="d-flex align-items-center"><div class="w-md d-flex justify-content-center align-items-center me-sm"><i class="fa-regular fa-sack-dollar fs-xs text-pretty-blue"></i></div>
# <span class="font-barlow text-gray-03">64K-118K Annually</span></div><div class="d-flex align-items-center"><div class="w-md d-flex justify-content-center align-items-center me-sm"><i class="fa-regular fa-trophy fs-xs text-pretty-blue"></i></div>
# ...
#                 Our Story
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://employers.builtin.com/careers/" target="_blank">
#                 Careers
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://builtin.com/our-staff" target="_blank">
#                 Our Staff Writers
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="/content-descriptions" target="_blank">
#                 Content Descriptions
#             </a></div></nav></div>
# <hr class="footer-hr px-lg"/>
# <div class="col-md"><div class="text-white mb-md font-barlow fw-medium fs-xl">Get Involved</div>
# <nav aria-labelledby="block-getinvolved-menu" class="flex-column small d-flex gap-md" role="navigation"><div><a class="nav-link text-white fs-sm fw-regular border-2 border-bottom border-mint special-footer-link" href="https://employers.builtin.com/membership?utm_medium=BIReferral&amp;utm_source=foremployers" target="_blank">
#                 Recruit With Built In
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://builtin.com/expert-contributors" target="_blank">
#                 Become an Expert Contributor
#             </a></div></nav></div>
# <hr class="footer-hr"/>
# <div class="col-md"><div class="text-white mb-md font-barlow fw-medium fs-xl">Resources</div>
# <nav aria-labelledby="block-resources-menu" class="flex-column small d-flex gap-md" role="navigation"><div><a class="nav-link text-white fs-sm fw-regular" href="https://knowledgebase.builtin.com/s/">
#                 Customer Support
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://form.jotform.com/223044927257054">
#                 Share Feedback
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://knowledgebase.builtin.com/s/contactsupport">
#                 Report a Bug
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://builtin.com/browse-jobs">
#                 Browse Jobs
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" data-drupal-link-system-path="tech-dictionary" href="https://builtin.com/tech-dictionary">
#                 Tech A-Z
#             </a></div></nav></div>
# <hr class="footer-hr"/>
# <div class="col-md"><div class="text-white mb-md font-barlow fw-medium fs-xl">Tech Hubs</div>
# <nav aria-labelledby="block-poweredbybuiltin-menu" class="flex-column small d-flex gap-md" role="navigation"><div><a class="nav-link text-white fs-sm fw-regular" href="https://www.builtinaustin.com" id="austin-link" target="_blank">
#                 Built In Austin
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://www.builtinboston.com" id="boston-link" target="_blank">
#                 Built In Boston
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://www.builtinchicago.org" id="chicago-link" target="_blank">
#                 Built In Chicago
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://www.builtincolorado.com" id="colorado-link" target="_blank">
#                 Built In Colorado
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://www.builtinla.com" id="la-link" target="_blank">
#                 Built In LA
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://www.builtinnyc.com" id="nyc-link" target="_blank">
#                 Built In NYC
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://www.builtinsf.com" id="san-francisco-link" target="_blank">
#                 Built In San Francisco
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://www.builtinseattle.com" id="seattle-link" target="_blank">
#                 Built In Seattle
#             </a></div>
# <div><a class="nav-link text-white fs-sm fw-regular" href="https://builtin.com/tech-hubs" target="_blank">
#                 See All Tech Hubs
#             </a></div></nav></div>
# <hr class="footer-hr"/></div><div class="container d-flex flex-column flex-md-row align-items-center align-items-md-start footer-bottom-nav-container gap-md gap-md-0 fs-xs py-lg mb-3xl mb-lg-0"><span class="text-center ms-md"> © Built In 2024</span>
# <nav aria-labelledby="block-footerbottom-menu" class="d-flex gap-md ms-md footer-bottom-nav" role="navigation"><a class="nav-link text-white fs-xs fw-regular" href="/learning-lab-user-agreement">
#                 Learning Lab User Agreement
#             </a><a class="nav-link text-white fs-xs fw-regular" href="/accessibility-statement">
#             Accessibility Statement
#         </a>
# <a class="nav-link text-white fs-xs fw-regular" href="/copyright-policy">
#             Copyright Policy
#         </a>
# <a class="nav-link text-white fs-xs fw-regular" href="/privacy-policy">
#             Privacy Policy
#         </a>
# <a class="nav-link text-white fs-xs fw-regular" href="/community-terms-of-use">
#             Terms of Use
#         </a>
# <a class="nav-link text-white fs-xs fw-regular do-not-sell-my-info" href="/california-do-not-sell-my-information">
#             Your Privacy Choices/Cookie Settings
#         </a>
# <a class="nav-link text-white fs-xs fw-regular" href="/ca-notice-collection">
#             CA Notice of Collection
#         </a></nav></div></div></div>
# </footer>
# <script crossorigin="anonymous" src="https://kit.fontawesome.com/e1bbd40aec.js"></script>
# <script src="https://static.builtin.com/dist/js/common.bundle.js"></script>
# <script src="/jobs/js/main.bundle.9b5440fac5331d3b0710.js"></script>
# <script src="https://static.builtin.com/dist/blaze/blaze-slider.min.js"></script>
# <script async="" crossorigin="" src="https://static.builtin.com/my-items/js/main.bundle.js"></script>
# <script>
#     (function(w){
#         w.bix.header.searchInit({
#             publicFilesDomain: "/sites/www.builtin.com/files",
#             regionId: "9",
#             staticAssetUrl: "https://static.builtin.com",
#             externalApi: "https://api.builtin.com"
#         });
#     })(window);
# </script>
# <script>
#     (async function(_window){
#         _window.bix.auth.init({
#             idpAuthority: "https://accounts.builtin.com",
#             idpClientId: "0fbc5326-c7c0-410d-9509-38c4d06bd29d",
#             redirectPath: "/auth/callback.html",
#             silentRedirectPath: "/auth/silent-renew.html",
#             logoutRedirectPath: "/user/logout",
#             externalApiUrl: "https://api.builtin.com",
#             regionId: "9",
#             domain: "builtin.com",
#             staticAssetBaseUrl: "https://static.builtin.com",
#             globalSiteUrl: "https://builtin.com"
#         });
#
#             _window.bix.auth.showUnauthenticatedDropdownItems();
#                 })(window);
# </script>
# <script type="text/javascript">
#     (function(w){
#         w.bix.eventTracking.init({
#             trackingBaseUrl: 'https://api.builtin.com',
#             trackingEventEndpoint: '/track/client-events',
#             trackingIdentityEndpoint: '/track/identity',
#             siteId: 9
#         });
#     })(window);
# </script>
# <script type="module">
#         Builtin.jobBoardInit({"criteria":{"remotePreferences":"","companySizes":"","regions":null,"categories":null,"subCategories":"","experiences":"","industry":"","subLocations":"","pageSize":10,"pageNumber":1,"search":"","isNational":true,"isElite":false,"isJobsBoard":true,"locationCoordinates":"","locationLabel":"United States","searchArea":"","companyId":null,"daysSinceUpdated":null,"earlyApplicant":false,"skills":"","state":null,"country":"USA"},"industryFilterOptions":[{"id":159,"name":"3D Printing","alias":"3d-printing","seoName":""},{"id":423,"name":"3PL: Third Party Logistics","alias":"3pl-third-party-logistics","seoName":""},{"id":160,"name":"AdTech","alias":"adtech","seoName":""},{"id":161,"name":"Aerospace","alias":"aerospace","seoName":""},{"id":162,"name":"Agency","alias":"agency","seoName":""},{"id":419,"name":"Agriculture","alias":"agriculture","seoName":""},{"id":371,"name":"Analytics","alias":"analytics-industry","seoName":""},{"id":163,"name":"Angel or VC Firm","alias":"angel-vcfirm","seoName":""},{"id":424,"name":"App development","alias":"app-development","seoName":""},{"id":422,"name":"Appliances","alias":"appliances","seoName":""},{"id":164,"name":"Artificial Intelligence","alias":"artificial-intelligence","seoName":""},{"id":437,"name":"Automation","alias":"automation","seoName":""},{"id":165,"name":"Automotive","alias":"automotive","seoName":""},{"id":166,"name":"Beauty","alias":"beauty","seoName":""},{"id":167,"name":"Big Data","alias":"big-data","seoName":""},{"id":435,"name":"Big Data Analytics","alias":"big-data-analytics","seoName":""},{"id":372,"name":"Biotech","alias":"biotech","seoName":""},{"id":168,"name":"Blockchain","alias":"blockchain","seoName":""},{"id":373,"name":"Business Intelligence","alias":"business-intelligence-industry","seoName":""},{"id":169,"name":"Cannabis","alias":"cannabis","seoName":""},{"id":421,"name":"Chemical","alias":"chemical","seoName":""},{"id":170,"name":"Cloud","alias":"cloud","seoName":""},{"id":172,"name":"Co-Working Space or Incubator","alias":"co-working-space-incubator","seoName":""},{"id":171,"name":"Computer Vision","alias":"computer-vision","seoName":""},{"id":374,"name":"Consulting","alias":"consulting","seoName":""},{"id":173,"name":"Consumer Web","alias":"consumer-web","seoName":""},{"id":432,"name":"Conversational AI","alias":"conversational-ai","seoName":""},{"id":174,"name":"Coupons","alias":"coupons","seoName":""},{"id":414,"name":"Cryptocurrency","alias":"cryptocurrency","seoName":""},{"id":415,"name":"Cybersecurity","alias":"cybersecurity","seoName":""},{"id":442,"name":"Data Privacy","alias":"data-privacy","seoName":""},{"id":360,"name":"Database","alias":"database","seoName":""},{"id":429,"name":"Defense","alias":"defense","seoName":""},{"id":416,"name":"Design","alias":"design","seoName":""},{"id":175,"name":"Digital Media","alias":"digital-media","seoName":""},{"id":176,"name":"eCommerce","alias":"ecommerce","seoName":""},{"id":177,"name":"Edtech","alias":"edtech","seoName":""},{"id":379,"name":"Energy","alias":"energy","seoName":""},{"id":178,"name":"Enterprise Web","alias":"enterprise-web","seoName":""},{"id":375,"name":"eSports","alias":"esports","seoName":""},{"id":179,"name":"Events","alias":"events","seoName":""},{"id":180,"name":"Fashion","alias":"fashion","seoName":""},{"id":413,"name":"Financial Services","alias":"financial-services","seoName":""},{"id":181,"name":"Fintech","alias":"fintech","seoName":""},{"id":182,"name":"Fitness","alias":"fitness","seoName":""},{"id":183,"name":"Food","alias":"food","seoName":""},{"id":184,"name":"Gaming","alias":"gaming","seoName":""},{"id":433,"name":"Generative AI","alias":"generative-ai","seoName":""},{"id":185,"name":"Greentech","alias":"greentech","seoName":""},{"id":186,"name":"Hardware","alias":"hardware-industry","seoName":""},{"id":187,"name":"Healthtech","alias":"healthtech","seoName":""},{"id":420,"name":"Hospitality","alias":"hospitality","seoName":""},{"id":188,"name":"HR Tech","ali ...
#     </script>
# <script type="text/javascript">
#         window.bix.eventTracking.logBuiltinTrackEvent('job_board_view', {'jobs':[{'id':3680837,'published_date':'2024-05-06T22:05:12','featured':false},{'id':3680835,'published_date':'2024-05-06T22:05:11','featured':false},{'id':3680836,'published_date':'2024-05-06T22:05:11','featured':false},{'id':3680834,'published_date':'2024-05-06T22:05:10','featured':false},{'id':3714740,'published_date':'2024-05-06T21:50:22','featured':false},{'id':3714739,'published_date':'2024-05-06T21:50:22','featured':false},{'id':3713368,'published_date':'2024-05-06T01:19:49','featured':false},{'id':3304124,'published_date':'2024-05-05T21:50:29','featured':false},{'id':3714734,'published_date':'2024-05-06T21:50:21','featured':false},{'id':3714735,'published_date':'2024-05-06T21:50:21','featured':false},{'id':3771690,'published_date':'2024-05-04T11:32:50','featured':false},{'id':3771677,'published_date':'2024-05-04T11:31:47','featured':false},{'id':3680675,'published_date':'2024-05-06T21:50:02','featured':false},{'id':3123806,'published_date':'2024-05-03T01:35:39','featured':false},{'id':3750320,'published_date':'2024-05-01T00:32:24','featured':false},{'id':3664091,'published_date':'2024-04-30T21:34:40','featured':false},{'id':3680658,'published_date':'2024-05-06T21:49:58','featured':false},{'id':3437486,'published_date':'2024-05-05T14:04:50','featured':false},{'id':3672932,'published_date':'2024-05-04T21:35:16','featured':false},{'id':3397147,'published_date':'2024-05-02T20:21:20','featured':false},{'id':3478521,'published_date':'2024-05-06T21:49:51','featured':false},{'id':3771688,'published_date':'2024-05-04T11:32:46','featured':false},{'id':3661495,'published_date':'2024-05-03T10:19:55','featured':false},{'id':3567827,'published_date':'2024-05-02T22:34:39','featured':false},{'id':3714704,'published_date':'2024-05-06T21:35:23','featured':false},{'id':3714700,'published_date':'2024-05-06T21:35:22','featured':false},{'id':3714703,'published_date':'2024-05-06T21:35:22','featured':false},{'id':3714696,'published_date':'2024-05-06T21:35:21','featured':false},{'id':3680645,'published_date':'2024-05-06T21:35:19','featured':false},{'id':3680643,'published_date':'2024-05-06T21:35:18','featured':false},{'id':3680644,'published_date':'2024-05-06T21:35:18','featured':false},{'id':3067245,'published_date':'2024-05-06T20:34:54','featured':false},{'id':3680603,'published_date':'2024-05-06T21:35:12','featured':false},{'id':3750077,'published_date':'2024-05-01T00:22:43','featured':false},{'id':3739182,'published_date':'2024-04-30T17:35:24','featured':false},{'id':3657061,'published_date':'2024-04-28T23:11:42','featured':false},{'id':3680591,'published_date':'2024-05-06T21:35:11','featured':false},{'id':3680584,'published_date':'2024-05-06T21:35:10','featured':false},{'id':3680582,'published_date':'2024-05-06T21:35:08','featured':false},{'id':3680578,'published_date':'2024-05-06T21:35:07','featured':false},{'id':3542599,'published_date':'2024-05-06T16:27:08','featured':true},{'id':3650590,'published_date':'2024-05-06T16:23:03','featured':true},{'id':3417451,'published_date':'2024-05-06T19:49:54','featured':true}],'filters':{'categories':'','company_sizes':'','experiences':'','industry':'','page':'1','per_page':'10','working_option':'','search':'','subcategories':'','days_since_posted':'','company_id':'','skills':'','early_applicant':'False','location':'United States','location_coordinates':'','search_area':''}});
#     </script>
# <script>(function(){if (!document.body) return;var js = "window['__CF$cv$params']={r:'87fccb91bf992027',t:'MTcxNTAzODYxNS41NjkwMDA='};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></body>
# </html>
